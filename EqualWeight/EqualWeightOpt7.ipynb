# %%
import yfinance as yf
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from gpflow.kernels import Matern32, Kernel
from gpflow.models import GPR
from gpflow import set_trainable
from sklearn.preprocessing import StandardScaler
import vectorbt as vbt
from datetime import datetime, timedelta
import ruptures as rpt
import warnings

warnings.filterwarnings("ignore", category=FutureWarning)

# Define the custom ChangePointKernel for Gaussian Process Regression
class ChangePointKernel(Kernel):
    def __init__(self, base_kernel, changepoints):
        super().__init__()
        self.base_kernel = base_kernel
        # changepoints: list of indices where a regime change is detected.
        self.changepoints = changepoints

    def get_region(self, X):
        cp = tf.constant(self.changepoints, dtype=X.dtype)
        regions = tf.searchsorted(cp, X[:, 0], side='right')
        return regions

    def K(self, X, X2=None):
        if X2 is None:
            X2 = X
        regions_X = self.get_region(X)
        regions_X2 = self.get_region(X2)
        regions_equal = tf.cast(tf.equal(tf.expand_dims(regions_X, 1), tf.expand_dims(regions_X2, 0)), X.dtype)
        base_cov = self.base_kernel.K(X, X2)
        return base_cov * regions_equal

    def K_diag(self, X):
        return self.base_kernel.K_diag(X)

def fetch_and_process_data(tickers, start_date, end_date):
    """Fetch data for multiple tickers and return price and returns DataFrames."""
    price_data = {}
    returns_data = {}
    
    # Add buffer days to ensure we have enough data
    start_date_obj = datetime.strptime(start_date, '%Y-%m-%d') - timedelta(days=30)
    start_date_buffer = start_date_obj.strftime('%Y-%m-%d')
    
    for ticker in tickers:
        try:
            # Use buffered start date to get more data
            data = yf.download(ticker, start=start_date_buffer, end=end_date)
            if data.empty:
                print(f"No data found for {ticker} between {start_date_buffer} and {end_date}")
                continue
                
            # Prefer "Adj Close" if available, otherwise "Close"
            if "Adj Close" in data.columns:
                price_series = data["Adj Close"].copy()
            else:
                price_series = data["Close"].copy()
                
            if isinstance(price_series, pd.DataFrame):
                price_series = price_series.squeeze()
                
            price_series.name = ticker
            
            # Check data quality
            missing_values = price_series.isna().sum()
            if missing_values > 0:
                print(f"Warning: {ticker} has {missing_values} missing values. Filling with ffill method.")
                price_series = price_series.fillna(method='ffill').fillna(method='bfill')
            
            returns = price_series.pct_change().dropna()
            
            # Add validation check for zero or near-zero returns
            zero_returns = (returns.abs() < 1e-8).sum()
            if zero_returns > len(returns) * 0.3:  # If more than 30% are zero returns
                print(f"Warning: {ticker} has {zero_returns} zero or near-zero returns (possible stale data)")
            
            # Standardize returns
            scaler = StandardScaler()
            std_returns = scaler.fit_transform(returns.values.reshape(-1, 1))
            valid_index = returns.index
            
            # Filter to the actual date range needed
            actual_start = datetime.strptime(start_date, '%Y-%m-%d')
            final_index = valid_index[valid_index >= pd.Timestamp(actual_start)]
            
            # Only keep data if we have enough for the given date range
            if len(final_index) > 0:
                price_data[ticker] = price_series
                returns_data[ticker] = pd.Series(
                    std_returns.flatten(), index=valid_index, name=f"{ticker}_stdret"
                )
            else:
                print(f"Not enough valid data for {ticker} in the specified date range after preprocessing")
                
        except Exception as e:
            print(f"Error fetching {ticker}: {e}")
    
    # Convert to DataFrames
    prices_df = pd.DataFrame({ticker: series for ticker, series in price_data.items()})
    returns_df = pd.DataFrame({ticker: series for ticker, series in returns_data.items()})
    
    # Filter to the actual date range needed
    actual_start = datetime.strptime(start_date, '%Y-%m-%d')
    prices_df = prices_df[prices_df.index >= pd.Timestamp(actual_start)]
    returns_df = returns_df[returns_df.index >= pd.Timestamp(actual_start)]
    
    return prices_df, returns_df

def detect_changepoints(returns, lookback_window, min_size=10):
    """Detect changepoints in return series with minimum segment size."""
    if len(returns) < min_size * 2:
        print(f"Warning: Series too short for changepoint detection ({len(returns)} points)")
        return []  # Return empty list if series is too short
        
    # Use ruptures to detect changepoints using an RBF model with a minimum segment size
    algo = rpt.Pelt(model="rbf", min_size=min_size).fit(returns.values)
    # Use the lookback_window as penalty; this is a simplified proxy for CPD LBW.
    result = algo.predict(pen=lookback_window)
    
    # Remove the last element which is just the length of the series
    if result and result[-1] == len(returns):
        result = result[:-1]
        
    # Print number of changepoints detected
    print(f"Detected {len(result)} changepoints in series of length {len(returns)}")
    
    return result

def generate_signals(returns, changepoints, train_ratio, epochs, 
                     dropout_rate, lstm_hidden_units, learning_rate, batch_size):
    """Generate trading signals using GPR+LSTM model."""
    # Use time index as a feature.
    X = np.arange(len(returns), dtype=np.float64).reshape(-1, 1)
    y = returns.values.reshape(-1, 1)
    
    # Use Gaussian Process Regression with the ChangePointKernel for trend extraction.
    base_kernel = Matern32()
    kernel = ChangePointKernel(base_kernel, changepoints)
    gpr = GPR(data=(X, y), kernel=kernel)
    set_trainable(gpr.likelihood.variance, False)
    trend = gpr.predict_f(X)[0].numpy().flatten()
    
    # Combine returns and trend to form a feature set.
    features = np.hstack([returns.values.reshape(-1, 1), trend.reshape(-1, 1)])
    
    # Ensure we have enough data for training
    if len(features) < 30:  # Minimum reasonable number for time series
        print("Warning: Not enough data points for effective training")
        # Return neutral signals if data is insufficient
        return np.ones(len(returns))
    
    # Ensure train_ratio doesn't create too small of a training set
    min_train_size = 30
    if int(len(features) * train_ratio) < min_train_size:
        train_ratio = max(0.5, min_train_size / len(features))
        print(f"Adjusted train_ratio to {train_ratio:.2f} to ensure minimum training size")
    
    split_index = int(len(features) * train_ratio)
    train_features = features[:split_index]
    train_labels = returns.values[:split_index]
    
    # Reshape features for LSTM input.
    train_features = train_features.reshape((train_features.shape[0], 1, train_features.shape[1]))
    
    # Add early stopping to prevent overfitting
    early_stop = tf.keras.callbacks.EarlyStopping(
        monitor='loss', patience=5, restore_best_weights=True
    )
    
    # Build the LSTM model.
    model = Sequential([
        LSTM(lstm_hidden_units, return_sequences=True,
             input_shape=(train_features.shape[1], train_features.shape[2]),
             activation='tanh',  # Explicit activation
             recurrent_activation='sigmoid'),  # Explicit recurrent activation
        Dropout(dropout_rate),
        LSTM(int(lstm_hidden_units / 2)),
        Dense(1, activation="tanh")
    ])
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate), loss="mse")
    
    # Train the model with early stopping
    model.fit(
        train_features, train_labels, 
        epochs=epochs, batch_size=min(batch_size, len(train_features)), 
        verbose=0,
        callbacks=[early_stop]
    )
    
    # Predict signals for all features.
    all_features = features.reshape((features.shape[0], 1, features.shape[1]))
    predicted_signals = model.predict(all_features, verbose=0).flatten()
    
    # Analyze signal distribution
    signal_mean = np.mean(predicted_signals)
    signal_std = np.std(predicted_signals)
    signal_min = np.min(predicted_signals)
    signal_max = np.max(predicted_signals)
    print(f"Signal stats - Mean: {signal_mean:.4f}, StdDev: {signal_std:.4f}, Min: {signal_min:.4f}, Max: {signal_max:.4f}")
    
    # Convert signals to binary (-1 or 1) for direction only
    positions = np.sign(predicted_signals)
    positions[positions == 0] = 1  # Convert any zeros to 1 (long)
    
    # Ensure we're getting a good mix of signals (at least some variation)
    long_pct = np.sum(positions > 0) / len(positions) * 100
    short_pct = np.sum(positions < 0) / len(positions) * 100
    print(f"Position distribution: {long_pct:.1f}% long, {short_pct:.1f}% short")
    
    # If signals are too one-sided (>95% same direction), add a warning
    if long_pct > 95 or short_pct > 95:
        print("Warning: Signals are very one-sided, might indicate poor model fit")
    
    return positions

def backtest_strategy_single_asset(price_series, positions):
    """Backtest strategy for a single asset with proper position alignment."""
    if isinstance(price_series, pd.DataFrame):
        price_series = price_series.squeeze()
    
    # Ensure positions align with price_series
    common_idx = price_series.index[:len(positions)]
    
    # Verify we have enough data points to proceed
    if len(common_idx) < 10:
        print(f"Warning: Not enough aligned data points for {price_series.name}")
        return None
    
    # Create properly aligned series
    aligned_prices = price_series.loc[common_idx]
    aligned_positions = pd.Series(positions, index=common_idx, name=price_series.name)
    
    # Debug info
    print(f"Backtesting {price_series.name}: {len(aligned_prices)} aligned price points with {len(aligned_positions)} position signals")
    
    # Convert positions to entries/exits
    entries = aligned_positions > 0
    exits = aligned_positions < 0
    
    # Count actual trading events
    entry_count = entries.sum()
    exit_count = exits.sum()
    print(f"Trading activity: {entry_count} entries, {exit_count} exits")
    
    # Ensure we have at least some trading activity
    if entry_count == 0 or exit_count == 0:
        print(f"Warning: Insufficient trading signals for {price_series.name}")
        if entry_count == 0 and exit_count == 0:
            # No trading signals at all, return None
            return None
    
    try:
        # Only use supported parameters for vectorbt Portfolio
        pf = vbt.Portfolio.from_signals(
            close=aligned_prices,
            entries=entries,
            exits=exits,
            size=1.0,  # Always use full size
            freq="1D",
            fees=0.001,
            direction='both'  # Allow both long and short
            # Removed unsupported parameters
        )
        
        # Verify position sizes
        max_gross_exposure = pf.gross_exposure().max()
        min_gross_exposure = pf.gross_exposure().min()
        mean_gross_exposure = pf.gross_exposure().mean()
        
        print(f"Exposure for {price_series.name}: Min={min_gross_exposure:.2%}, Mean={mean_gross_exposure:.2%}, Max={max_gross_exposure:.2%}")
        
        return pf
    except Exception as e:
        print(f"Error in backtesting {price_series.name}: {e}")
        return None

def backtest_equal_weight_portfolio(prices_df, signals_dict):
    """Backtest a portfolio with equal weights across assets."""
    # Create a dictionary to store individual asset performance
    asset_results = {}
    
    for ticker in prices_df.columns:
        if ticker in signals_dict:
            # Get price series and signals for this ticker
            price_series = prices_df[ticker]
            positions = signals_dict[ticker]
            
            print(f"\nProcessing {ticker}:")
            print(f"  - Price series: {len(price_series)} points from {price_series.index[0].date()} to {price_series.index[-1].date()}")
            print(f"  - Position signals: {len(positions)} points")
            
            # Backtest the individual asset
            pf = backtest_strategy_single_asset(price_series, positions)
            if pf is not None:
                asset_results[ticker] = pf
            else:
                print(f"Skipping {ticker} due to backtesting issues")
    
    # Calculate the equal weight allocation (1/n for each asset)
    n_assets = len(asset_results)
    if n_assets == 0:
        print("No valid assets to create portfolio!")
        return None, {}
        
    weight_per_asset = 1.0 / n_assets
    print(f"\nCreating equal-weight portfolio with {n_assets} assets, {weight_per_asset:.2%} weight each")
    
    # Create a combined DataFrame for returns
    combined_returns = pd.DataFrame()
    
    for ticker, pf in asset_results.items():
        returns = pf.returns()
        if not returns.empty:
            combined_returns[ticker] = returns
    
    # Calculate equal-weighted portfolio returns
    if not combined_returns.empty:
        # Replace NaN with 0 for calculation
        combined_returns.fillna(0, inplace=True)
        portfolio_returns = (combined_returns * weight_per_asset).sum(axis=1)
        
        # Calculate cumulative returns
        portfolio_cumulative = (1 + portfolio_returns).cumprod()
        
        # Enhanced portfolio stats
        sharpe = portfolio_returns.mean() / portfolio_returns.std() * np.sqrt(252) if len(portfolio_returns) > 0 else 0
        total_return = portfolio_cumulative.iloc[-1] - 1 if len(portfolio_cumulative) > 0 else 0
        max_dd = (portfolio_cumulative / portfolio_cumulative.cummax() - 1).min() if len(portfolio_cumulative) > 0 else 0
        win_rate = np.sum(portfolio_returns > 0) / len(portfolio_returns) if len(portfolio_returns) > 0 else 0
        
        # Calculate annualized return
        days = (portfolio_returns.index[-1] - portfolio_returns.index[0]).days
        years = days / 365.0
        annualized_return = (1 + total_return) ** (1 / years) - 1 if years > 0 else 0
        
        portfolio_stats = {
            "total_return": total_return,
            "annualized_return": annualized_return,
            "sharpe_ratio": sharpe,
            "max_drawdown": max_dd,
            "win_rate": win_rate,
            "num_days": days
        }
        
        # Create mock portfolio object
        mock_portfolio = type('obj', (object,), {
            'stats': lambda: portfolio_stats,
            'returns': lambda: portfolio_returns,
            'cumulative_returns': lambda: portfolio_cumulative
        })
        
        print(f"\nPortfolio Performance:")
        print(f"  - Total Return: {total_return:.2%}")
        print(f"  - Annualized Return: {annualized_return:.2%}")
        print(f"  - Sharpe Ratio: {sharpe:.2f}")
        print(f"  - Max Drawdown: {max_dd:.2%}")
        print(f"  - Win Rate: {win_rate:.2%}")
        
        return mock_portfolio, asset_results
    else:
        print("No valid returns data to create portfolio!")
        return None, {}

def main():
    # Fixed hyperparameters.
    params = {
        'batch_size': 64,  # Reduced from 128 to avoid overfitting with small datasets
        'dropout_rate': 0.25,  # Increased from 0.2 for better regularization
        'learning_rate': 0.001,
        'lookback_window': 21,
        'lstm_hidden_units': 40,
        'epochs': 50,
        'train_ratio': 0.8
    }
    
    # Updated dictionary of top cryptocurrencies by year with -USD suffix
    top_cryptos = {
        "2019": ["BTC-USD", "ETH-USD", "XRP-USD", "BCH-USD", "EOS-USD", "LTC-USD", "XLM-USD", "ADA-USD", "TRX-USD", "BSV-USD"],
        "2020": ["BTC-USD", "ETH-USD", "XRP-USD", "BCH-USD", "LTC-USD", "EOS-USD", "BNB-USD", "BSV-USD", "ADA-USD", "XTZ-USD"],
        "2021": ["BTC-USD", "ETH-USD", "XRP-USD", "LTC-USD", "BCH-USD", "ADA-USD", "DOT1-USD", "LINK-USD", "BNB-USD", "XLM-USD"],
        "2022": ["BTC-USD", "ETH-USD", "BNB-USD", "SOL-USD", "ADA-USD", "XRP-USD", "DOT1-USD", "LUNA1-USD", "AVAX-USD", "DOGE-USD"],  # Fixed LUNA -> LUNA1-USD
        "2023": ["BTC-USD", "ETH-USD", "BNB-USD", "XRP-USD", "ADA-USD", "DOGE-USD", "MATIC-USD", "DOT1-USD", "LTC-USD", "SHIB-USD"],
        "2024": ["BTC-USD", "ETH-USD", "BNB-USD", "XRP-USD", "ADA-USD", "DOGE-USD", "SOL-USD", "DOT1-USD", "LTC-USD", "AVAX-USD"],
        "2025": ["BTC-USD", "ETH-USD", "BNB-USD", "XRP-USD", "ADA-USD", "DOGE-USD", "SOL-USD", "DOT1-USD", "LTC-USD", "AVAX-USD"]
    }

    # Define periods (one per year)
    periods = []
    for year in range(2019, 2025):
        period_label = str(year)
        start_date = f"{year}-01-01"
        end_date = f"{year}-12-31"
        periods.append((period_label, start_date, end_date))
    # YTD 2025 using current date
    periods.append(("2025_YTD", "2025-01-01", "2025-03-07"))

    results = []

    # Loop over each period and backtest the respective top cryptocurrencies for that year
    for period_label, start_date, end_date in periods:
        year = period_label.split("_")[0]  # Extract year from period label
        cryptos_for_year = top_cryptos.get(year, [])
        
        print(f"\n{'='*80}")
        print(f"Processing period {period_label} ({start_date} to {end_date})")
        print(f"Cryptocurrencies: {', '.join(cryptos_for_year)}")
        print(f"{'='*80}")
        
        # Fetch all data for the period
        prices_df, returns_df = fetch_and_process_data(cryptos_for_year, start_date, end_date)
        
        if prices_df.empty or returns_df.empty:
            print(f"No data available for period {period_label}")
            continue
        
        # Debug info about the data
        print(f"\nData summary:")
        print(f"  - Price data: {len(prices_df)} days from {prices_df.index[0].date() if not prices_df.empty else 'N/A'} to {prices_df.index[-1].date() if not prices_df.empty else 'N/A'}")
        print(f"  - Returns data: {len(returns_df)} days")
        print(f"  - Available tickers: {', '.join(prices_df.columns)}")
        
        # Generate signals for each cryptocurrency
        signals_dict = {}
        
        for crypto in cryptos_for_year:
            if crypto in returns_df.columns:
                try:
                    print(f"\n{'-'*60}")
                    print(f"Processing {crypto} for period {period_label}")
                    
                    returns = returns_df[crypto]
                    if len(returns) < params['lookback_window']:
                        print(f"Not enough data for {crypto} in period {period_label}. Skipping.")
                        continue
                    
                    print(f"Detecting changepoints for {crypto}...")
                    changepoints = detect_changepoints(returns, lookback_window=params['lookback_window'])
                    
                    print(f"Generating trading signals for {crypto}...")
                    positions = generate_signals(
                        returns, changepoints,
                        train_ratio=params['train_ratio'],
                        epochs=params['epochs'],
                        dropout_rate=params['dropout_rate'],
                        lstm_hidden_units=params['lstm_hidden_units'],
                        learning_rate=params['learning_rate'],
                        batch_size=params['batch_size']
                    )
                    
                    # Make sure positions match the length of the returns
                    signals_dict[crypto] = positions
                    print(f"Generated {len(positions)} position signals for {crypto}")
                    
                except Exception as e:
                    print(f"Error generating signals for {crypto}: {e}")
                    import traceback
                    traceback.print_exc()
        
        # Backtest with equal weight allocation
        portfolio, asset_portfolios = backtest_equal_weight_portfolio(prices_df, signals_dict)
        
        if portfolio:
            # Record main portfolio results
            portfolio_stats = portfolio.stats()
            result = {
                "period": period_label,
                "strategy": "Equal Weight Portfolio",
                "num_assets": len(asset_portfolios),
                **{key: str(value) if pd.isna(value) else value for key, value in portfolio_stats.items()}
            }
            results.append(result)
            
            # Also record individual asset results
            for crypto, pf in asset_portfolios.items():
                if hasattr(pf, 'stats'):
                    try:
                        asset_stats = pf.stats()
                        asset_result = {
                            "period": period_label,
                            "crypto": crypto,
                            "strategy": "Individual Asset",
                            **{key: str(value) if pd.isna(value) else value for key, value in asset_stats.items()}
                        }
                        results.append(asset_result)
                    except Exception as e:
                        print(f"Error extracting stats for {crypto}: {e}")

    # Save all summary results into a DataFrame.
    if results:  # Check if we have results before creating DataFrame
        results_df = pd.DataFrame(results)
        print("\nBacktest Results:")
        print(results_df)
        
        # Save the DataFrame to a CSV file.
        results_df.to_csv("Backtested/equal_weight_8.csv", index=False)
        
        # Calculate and display yearly performance comparison
        portfolio_results = results_df[results_df["strategy"] == "Equal Weight Portfolio"]
        if not portfolio_results.empty:
            print("\nEqual Weight Portfolio Performance by Year:")
            yearly_perf = portfolio_results[["period", "total_return", "sharpe_ratio", "max_drawdown"]]
            print(yearly_perf)
    else:
        print("\nNo results generated. Check the data and parameters.")

if __name__ == "__main__":
    main()
# Out:
# ================================================================================
# Processing period 2019 (2019-01-01 to 2019-12-31)
# Cryptocurrencies: BTC-USD, ETH-USD, XRP-USD, BCH-USD, EOS-USD, LTC-USD, XLM-USD, ADA-USD, TRX-USD, BSV-USD
# ================================================================================
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Data summary:
#   - Price data: 364 days from 2019-01-01 to 2019-12-30
#   - Returns data: 364 days
#   - Available tickers: BTC-USD, ETH-USD, XRP-USD, BCH-USD, EOS-USD, LTC-USD, XLM-USD, ADA-USD, TRX-USD, BSV-USD
#
# ------------------------------------------------------------
# Processing BTC-USD for period 2019
# Detecting changepoints for BTC-USD...
# Detected 0 changepoints in series of length 364
# Generating trading signals for BTC-USD...
# /opt/homebrew/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Signal stats - Mean: -0.0176, StdDev: 0.5859, Min: -0.9942, Max: 0.9981
# Position distribution: 45.3% long, 54.7% short
# Generated 364 position signals for BTC-USD
#
# ------------------------------------------------------------
# Processing ETH-USD for period 2019
# Detecting changepoints for ETH-USD...
# Detected 0 changepoints in series of length 364
# Generating trading signals for ETH-USD...
# Signal stats - Mean: -0.0088, StdDev: 0.5982, Min: -0.9973, Max: 0.9968
# Position distribution: 47.0% long, 53.0% short
# Generated 364 position signals for ETH-USD
#
# ------------------------------------------------------------
# Processing XRP-USD for period 2019
# Detecting changepoints for XRP-USD...
# Detected 0 changepoints in series of length 364
# Generating trading signals for XRP-USD...
# Signal stats - Mean: -0.0196, StdDev: 0.5808, Min: -0.9802, Max: 0.9983
# Position distribution: 46.2% long, 53.8% short
# Generated 364 position signals for XRP-USD
#
# ------------------------------------------------------------
# Processing BCH-USD for period 2019
# Detecting changepoints for BCH-USD...
# Detected 0 changepoints in series of length 364
# Generating trading signals for BCH-USD...
# Signal stats - Mean: -0.0212, StdDev: 0.5224, Min: -0.9835, Max: 0.9970
# Position distribution: 45.3% long, 54.7% short
# Generated 364 position signals for BCH-USD
#
# ------------------------------------------------------------
# Processing EOS-USD for period 2019
# Detecting changepoints for EOS-USD...
# Detected 0 changepoints in series of length 364
# Generating trading signals for EOS-USD...
# Signal stats - Mean: -0.0019, StdDev: 0.5817, Min: -0.9970, Max: 0.9972
# Position distribution: 49.2% long, 50.8% short
# Generated 364 position signals for EOS-USD
#
# ------------------------------------------------------------
# Processing LTC-USD for period 2019
# Detecting changepoints for LTC-USD...
# Detected 0 changepoints in series of length 364
# Generating trading signals for LTC-USD...
# Signal stats - Mean: -0.0284, StdDev: 0.6117, Min: -0.9905, Max: 0.9991
# Position distribution: 46.7% long, 53.3% short
# Generated 364 position signals for LTC-USD
#
# ------------------------------------------------------------
# Processing XLM-USD for period 2019
# Detecting changepoints for XLM-USD...
# Detected 0 changepoints in series of length 364
# Generating trading signals for XLM-USD...
# Signal stats - Mean: -0.0171, StdDev: 0.6096, Min: -0.9846, Max: 0.9984
# Position distribution: 48.9% long, 51.1% short
# Generated 364 position signals for XLM-USD
#
# ------------------------------------------------------------
# Processing ADA-USD for period 2019
# Detecting changepoints for ADA-USD...
# Detected 0 changepoints in series of length 364
# Generating trading signals for ADA-USD...
# Signal stats - Mean: -0.0160, StdDev: 0.6526, Min: -0.9968, Max: 0.9982
# Position distribution: 49.2% long, 50.8% short
# Generated 364 position signals for ADA-USD
#
# ------------------------------------------------------------
# Processing TRX-USD for period 2019
# Detecting changepoints for TRX-USD...
# Detected 0 changepoints in series of length 364
# Generating trading signals for TRX-USD...
# Signal stats - Mean: -0.0267, StdDev: 0.6266, Min: -0.9960, Max: 0.9970
# Position distribution: 47.3% long, 52.7% short
# Generated 364 position signals for TRX-USD
#
# ------------------------------------------------------------
# Processing BSV-USD for period 2019
# Detecting changepoints for BSV-USD...
# Detected 0 changepoints in series of length 364
# Generating trading signals for BSV-USD...
# Signal stats - Mean: -0.0496, StdDev: 0.5015, Min: -0.9712, Max: 0.9969
# Position distribution: 44.5% long, 55.5% short
# Generated 364 position signals for BSV-USD
#
# Processing BTC-USD:
#   - Price series: 364 points from 2019-01-01 to 2019-12-30
#   - Position signals: 364 points
# Backtesting BTC-USD: 364 aligned price points with 364 position signals
# Trading activity: 165 entries, 199 exits
# Exposure for BTC-USD: Min=30.65%, Mean=47.99%, Max=100.00%
#
# Processing ETH-USD:
#   - Price series: 364 points from 2019-01-01 to 2019-12-30
#   - Position signals: 364 points
# Backtesting ETH-USD: 364 aligned price points with 364 position signals
# Trading activity: 171 entries, 193 exits
# Exposure for ETH-USD: Min=49.64%, Mean=133.30%, Max=2250.41%
#
# Processing XRP-USD:
#   - Price series: 364 points from 2019-01-01 to 2019-12-30
#   - Position signals: 364 points
# Backtesting XRP-USD: 364 aligned price points with 364 position signals
# Trading activity: 168 entries, 196 exits
# Exposure for XRP-USD: Min=-0.47%, Mean=-0.02%, Max=0.47%
#
# Processing BCH-USD:
#   - Price series: 364 points from 2019-01-01 to 2019-12-30
#   - Position signals: 364 points
# Backtesting BCH-USD: 364 aligned price points with 364 position signals
# Trading activity: 165 entries, 199 exits
# Exposure for BCH-USD: Min=18.17%, Mean=55.15%, Max=100.00%
#
# Processing EOS-USD:
#   - Price series: 364 points from 2019-01-01 to 2019-12-30
#   - Position signals: 364 points
# Backtesting EOS-USD: 364 aligned price points with 364 position signals
# Trading activity: 179 entries, 185 exits
# Exposure for EOS-USD: Min=-9.37%, Mean=-0.19%, Max=8.47%
#
# Processing LTC-USD:
#   - Price series: 364 points from 2019-01-01 to 2019-12-30
#   - Position signals: 364 points
# Backtesting LTC-USD: 364 aligned price points with 364 position signals
# Trading activity: 170 entries, 194 exits
# Exposure for LTC-USD: Min=-9716.58%, Mean=85.84%, Max=9059.06%
#
# Processing XLM-USD:
#   - Price series: 364 points from 2019-01-01 to 2019-12-30
#   - Position signals: 364 points
# Backtesting XLM-USD: 364 aligned price points with 364 position signals
# Trading activity: 178 entries, 186 exits
# Exposure for XLM-USD: Min=-0.14%, Mean=0.00%, Max=0.14%
#
# Processing ADA-USD:
#   - Price series: 364 points from 2019-01-01 to 2019-12-30
#   - Position signals: 364 points
# Backtesting ADA-USD: 364 aligned price points with 364 position signals
# Trading activity: 179 entries, 185 exits
# Exposure for ADA-USD: Min=-0.10%, Mean=0.00%, Max=0.10%
#
# Processing TRX-USD:
#   - Price series: 364 points from 2019-01-01 to 2019-12-30
#   - Position signals: 364 points
# Backtesting TRX-USD: 364 aligned price points with 364 position signals
# Trading activity: 172 entries, 192 exits
# Exposure for TRX-USD: Min=-0.04%, Mean=-0.00%, Max=0.04%
#
# Processing BSV-USD:
#   - Price series: 364 points from 2019-01-01 to 2019-12-30
#   - Position signals: 364 points
# Backtesting BSV-USD: 364 aligned price points with 364 position signals
# Trading activity: 162 entries, 202 exits
# Exposure for BSV-USD: Min=-2311.19%, Mean=44.21%, Max=791.99%
#
# Creating equal-weight portfolio with 10 assets, 10.00% weight each
#
# Portfolio Performance:
#   - Total Return: -40.39%
#   - Annualized Return: -40.56%
#   - Sharpe Ratio: -0.53
#   - Max Drawdown: -61.70%
#   - Win Rate: 46.98%
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ================================================================================
# Processing period 2020 (2020-01-01 to 2020-12-31)
# Cryptocurrencies: BTC-USD, ETH-USD, XRP-USD, BCH-USD, LTC-USD, EOS-USD, BNB-USD, BSV-USD, ADA-USD, XTZ-USD
# ================================================================================
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# /opt/homebrew/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Data summary:
#   - Price data: 365 days from 2020-01-01 to 2020-12-30
#   - Returns data: 365 days
#   - Available tickers: BTC-USD, ETH-USD, XRP-USD, BCH-USD, LTC-USD, EOS-USD, BNB-USD, BSV-USD, ADA-USD, XTZ-USD
#
# ------------------------------------------------------------
# Processing BTC-USD for period 2020
# Detecting changepoints for BTC-USD...
# Detected 0 changepoints in series of length 365
# Generating trading signals for BTC-USD...
# Signal stats - Mean: 0.0094, StdDev: 0.5794, Min: -0.9974, Max: 0.9919
# Position distribution: 48.2% long, 51.8% short
# Generated 365 position signals for BTC-USD
#
# ------------------------------------------------------------
# Processing ETH-USD for period 2020
# Detecting changepoints for ETH-USD...
# Detected 0 changepoints in series of length 365
# Generating trading signals for ETH-USD...
# Signal stats - Mean: 0.0188, StdDev: 0.6143, Min: -0.9982, Max: 0.9933
# Position distribution: 50.1% long, 49.9% short
# Generated 365 position signals for ETH-USD
#
# ------------------------------------------------------------
# Processing XRP-USD for period 2020
# Detecting changepoints for XRP-USD...
# Detected 0 changepoints in series of length 365
# Generating trading signals for XRP-USD...
# Signal stats - Mean: -0.0069, StdDev: 0.5148, Min: -0.9936, Max: 0.9942
# Position distribution: 49.3% long, 50.7% short
# Generated 365 position signals for XRP-USD
#
# ------------------------------------------------------------
# Processing BCH-USD for period 2020
# Detecting changepoints for BCH-USD...
# Detected 0 changepoints in series of length 365
# Generating trading signals for BCH-USD...
# Signal stats - Mean: -0.0029, StdDev: 0.5854, Min: -0.9970, Max: 0.9977
# Position distribution: 47.7% long, 52.3% short
# Generated 365 position signals for BCH-USD
#
# ------------------------------------------------------------
# Processing LTC-USD for period 2020
# Detecting changepoints for LTC-USD...
# Detected 0 changepoints in series of length 365
# Generating trading signals for LTC-USD...
# Signal stats - Mean: -0.0015, StdDev: 0.6055, Min: -0.9982, Max: 0.9849
# Position distribution: 48.5% long, 51.5% short
# Generated 365 position signals for LTC-USD
#
# ------------------------------------------------------------
# Processing EOS-USD for period 2020
# Detecting changepoints for EOS-USD...
# Detected 0 changepoints in series of length 365
# Generating trading signals for EOS-USD...
# Signal stats - Mean: 0.0081, StdDev: 0.5542, Min: -0.9956, Max: 0.9918
# Position distribution: 49.9% long, 50.1% short
# Generated 365 position signals for EOS-USD
#
# ------------------------------------------------------------
# Processing BNB-USD for period 2020
# Detecting changepoints for BNB-USD...
# Detected 0 changepoints in series of length 365
# Generating trading signals for BNB-USD...
# Signal stats - Mean: 0.0278, StdDev: 0.6179, Min: -0.9980, Max: 0.9932
# Position distribution: 51.5% long, 48.5% short
# Generated 365 position signals for BNB-USD
#
# ------------------------------------------------------------
# Processing BSV-USD for period 2020
# Detecting changepoints for BSV-USD...
# Detected 0 changepoints in series of length 365
# Generating trading signals for BSV-USD...
# Signal stats - Mean: -0.0332, StdDev: 0.4417, Min: -0.9773, Max: 0.9947
# Position distribution: 41.1% long, 58.9% short
# Generated 365 position signals for BSV-USD
#
# ------------------------------------------------------------
# Processing ADA-USD for period 2020
# Detecting changepoints for ADA-USD...
# Detected 0 changepoints in series of length 365
# Generating trading signals for ADA-USD...
# Signal stats - Mean: -0.0010, StdDev: 0.6398, Min: -0.9986, Max: 0.9950
# Position distribution: 48.8% long, 51.2% short
# Generated 365 position signals for ADA-USD
#
# ------------------------------------------------------------
# Processing XTZ-USD for period 2020
# Detecting changepoints for XTZ-USD...
# Detected 0 changepoints in series of length 365
# Generating trading signals for XTZ-USD...
# Signal stats - Mean: -0.0160, StdDev: 0.6300, Min: -0.9976, Max: 0.9949
# Position distribution: 50.1% long, 49.9% short
# Generated 365 position signals for XTZ-USD
#
# Processing BTC-USD:
#   - Price series: 365 points from 2020-01-01 to 2020-12-30
#   - Position signals: 365 points
# Backtesting BTC-USD: 365 aligned price points with 365 position signals
# Trading activity: 176 entries, 189 exits
# Exposure for BTC-USD: Min=25.66%, Mean=42.28%, Max=66.70%
#
# Processing ETH-USD:
#   - Price series: 365 points from 2020-01-01 to 2020-12-30
#   - Position signals: 365 points
# Backtesting ETH-USD: 365 aligned price points with 365 position signals
# Trading activity: 183 entries, 182 exits
# Exposure for ETH-USD: Min=17.41%, Mean=43.55%, Max=100.00%
#
# Processing XRP-USD:
#   - Price series: 365 points from 2020-01-01 to 2020-12-30
#   - Position signals: 365 points
# Backtesting XRP-USD: 365 aligned price points with 365 position signals
# Trading activity: 180 entries, 185 exits
# Exposure for XRP-USD: Min=-0.64%, Mean=-0.00%, Max=0.69%
#
# Processing BCH-USD:
#   - Price series: 365 points from 2020-01-01 to 2020-12-30
#   - Position signals: 365 points
# Backtesting BCH-USD: 365 aligned price points with 365 position signals
# Trading activity: 174 entries, 191 exits
# Exposure for BCH-USD: Min=18.33%, Mean=30.65%, Max=100.00%
#
# Processing LTC-USD:
#   - Price series: 365 points from 2020-01-01 to 2020-12-30
#   - Position signals: 365 points
# Backtesting LTC-USD: 365 aligned price points with 365 position signals
# Trading activity: 177 entries, 188 exits
# Exposure for LTC-USD: Min=-8817.03%, Mean=198.51%, Max=24119.87%
#
# Processing EOS-USD:
#   - Price series: 365 points from 2020-01-01 to 2020-12-30
#   - Position signals: 365 points
# Backtesting EOS-USD: 365 aligned price points with 365 position signals
# Trading activity: 182 entries, 183 exits
# Exposure for EOS-USD: Min=-6.07%, Mean=-0.05%, Max=5.41%
#
# Processing BNB-USD:
#   - Price series: 365 points from 2020-01-01 to 2020-12-30
#   - Position signals: 365 points
# Backtesting BNB-USD: 365 aligned price points with 365 position signals
# Trading activity: 188 entries, 177 exits
# Exposure for BNB-USD: Min=-155.16%, Mean=-9.34%, Max=38.28%
#
# Processing BSV-USD:
#   - Price series: 365 points from 2020-01-01 to 2020-12-30
#   - Position signals: 365 points
# Backtesting BSV-USD: 365 aligned price points with 365 position signals
# Trading activity: 150 entries, 215 exits
# Exposure for BSV-USD: Min=-3652.75%, Mean=-107.54%, Max=394.42%
#
# Processing ADA-USD:
#   - Price series: 365 points from 2020-01-01 to 2020-12-30
#   - Position signals: 365 points
# Backtesting ADA-USD: 365 aligned price points with 365 position signals
# Trading activity: 178 entries, 187 exits
# Exposure for ADA-USD: Min=-0.18%, Mean=-0.00%, Max=0.19%
#
# Processing XTZ-USD:
#   - Price series: 365 points from 2020-01-01 to 2020-12-30
#   - Position signals: 365 points
# Backtesting XTZ-USD: 365 aligned price points with 365 position signals
# Trading activity: 183 entries, 182 exits
# Exposure for XTZ-USD: Min=-4.58%, Mean=-0.04%, Max=4.42%
#
# Creating equal-weight portfolio with 10 assets, 10.00% weight each
#
# Portfolio Performance:
#   - Total Return: -61.85%
#   - Annualized Return: -61.95%
#   - Sharpe Ratio: -0.99
#   - Max Drawdown: -68.99%
#   - Win Rate: 46.58%
# [*********************100%***********************]  1 of 1 completed
# ================================================================================
# Processing period 2021 (2021-01-01 to 2021-12-31)
# Cryptocurrencies: BTC-USD, ETH-USD, XRP-USD, LTC-USD, BCH-USD, ADA-USD, DOT1-USD, LINK-USD, BNB-USD, XLM-USD
# ================================================================================
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['DOT1-USD']: YFPricesMissingError('possibly delisted; no price data found  (1d 2020-12-02 -> 2021-12-31)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# No data found for DOT1-USD between 2020-12-02 and 2021-12-31
# [*********************100%***********************]  1 of 1 completed
# /opt/homebrew/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Data summary:
#   - Price data: 364 days from 2021-01-01 to 2021-12-30
#   - Returns data: 364 days
#   - Available tickers: BTC-USD, ETH-USD, XRP-USD, LTC-USD, BCH-USD, ADA-USD, LINK-USD, BNB-USD, XLM-USD
#
# ------------------------------------------------------------
# Processing BTC-USD for period 2021
# Detecting changepoints for BTC-USD...
# Detected 0 changepoints in series of length 364
# Generating trading signals for BTC-USD...
# Signal stats - Mean: -0.0302, StdDev: 0.6755, Min: -0.9963, Max: 0.9991
# Position distribution: 44.8% long, 55.2% short
# Generated 364 position signals for BTC-USD
#
# ------------------------------------------------------------
# Processing ETH-USD for period 2021
# Detecting changepoints for ETH-USD...
# Detected 0 changepoints in series of length 364
# Generating trading signals for ETH-USD...
# Signal stats - Mean: -0.0077, StdDev: 0.6789, Min: -0.9985, Max: 0.9980
# Position distribution: 50.0% long, 50.0% short
# Generated 364 position signals for ETH-USD
#
# ------------------------------------------------------------
# Processing XRP-USD for period 2021
# Detecting changepoints for XRP-USD...
# Detected 0 changepoints in series of length 364
# Generating trading signals for XRP-USD...
# Signal stats - Mean: -0.0096, StdDev: 0.5801, Min: -0.9816, Max: 0.9985
# Position distribution: 47.3% long, 52.7% short
# Generated 364 position signals for XRP-USD
#
# ------------------------------------------------------------
# Processing LTC-USD for period 2021
# Detecting changepoints for LTC-USD...
# Detected 0 changepoints in series of length 364
# Generating trading signals for LTC-USD...
# Signal stats - Mean: -0.0034, StdDev: 0.6358, Min: -0.9984, Max: 0.9974
# Position distribution: 50.0% long, 50.0% short
# Generated 364 position signals for LTC-USD
#
# ------------------------------------------------------------
# Processing BCH-USD for period 2021
# Detecting changepoints for BCH-USD...
# Detected 0 changepoints in series of length 364
# Generating trading signals for BCH-USD...
# Signal stats - Mean: -0.0162, StdDev: 0.5978, Min: -0.9945, Max: 0.9986
# Position distribution: 49.5% long, 50.5% short
# Generated 364 position signals for BCH-USD
#
# ------------------------------------------------------------
# Processing ADA-USD for period 2021
# Detecting changepoints for ADA-USD...
# Detected 0 changepoints in series of length 364
# Generating trading signals for ADA-USD...
# Signal stats - Mean: -0.0588, StdDev: 0.6297, Min: -0.9794, Max: 0.9986
# Position distribution: 43.7% long, 56.3% short
# Generated 364 position signals for ADA-USD
#
# ------------------------------------------------------------
# Processing LINK-USD for period 2021
# Detecting changepoints for LINK-USD...
# Detected 0 changepoints in series of length 364
# Generating trading signals for LINK-USD...
# Signal stats - Mean: 0.0079, StdDev: 0.6893, Min: -0.9972, Max: 0.9976
# Position distribution: 50.8% long, 49.2% short
# Generated 364 position signals for LINK-USD
#
# ------------------------------------------------------------
# Processing BNB-USD for period 2021
# Detecting changepoints for BNB-USD...
# Detected 0 changepoints in series of length 364
# Generating trading signals for BNB-USD...
# Signal stats - Mean: -0.0422, StdDev: 0.6006, Min: -0.9899, Max: 0.9987
# Position distribution: 44.5% long, 55.5% short
# Generated 364 position signals for BNB-USD
#
# ------------------------------------------------------------
# Processing XLM-USD for period 2021
# Detecting changepoints for XLM-USD...
# Detected 0 changepoints in series of length 364
# Generating trading signals for XLM-USD...
# Signal stats - Mean: -0.0132, StdDev: 0.5962, Min: -0.9819, Max: 0.9989
# Position distribution: 47.3% long, 52.7% short
# Generated 364 position signals for XLM-USD
#
# Processing BTC-USD:
#   - Price series: 364 points from 2021-01-01 to 2021-12-30
#   - Position signals: 364 points
# Backtesting BTC-USD: 364 aligned price points with 364 position signals
# Trading activity: 163 entries, 201 exits
# Exposure for BTC-USD: Min=31.79%, Mean=42.74%, Max=100.00%
#
# Processing ETH-USD:
#   - Price series: 364 points from 2021-01-01 to 2021-12-30
#   - Position signals: 364 points
# Backtesting ETH-USD: 364 aligned price points with 364 position signals
# Trading activity: 182 entries, 182 exits
# Exposure for ETH-USD: Min=30.75%, Mean=49.97%, Max=100.00%
#
# Processing XRP-USD:
#   - Price series: 364 points from 2021-01-01 to 2021-12-30
#   - Position signals: 364 points
# Backtesting XRP-USD: 364 aligned price points with 364 position signals
# Trading activity: 172 entries, 192 exits
# Exposure for XRP-USD: Min=-1.83%, Mean=-0.05%, Max=1.84%
#
# Processing LTC-USD:
#   - Price series: 364 points from 2021-01-01 to 2021-12-30
#   - Position signals: 364 points
# Backtesting LTC-USD: 364 aligned price points with 364 position signals
# Trading activity: 182 entries, 182 exits
# Exposure for LTC-USD: Min=-17503.64%, Mean=111.63%, Max=11442.16%
#
# Processing BCH-USD:
#   - Price series: 364 points from 2021-01-01 to 2021-12-30
#   - Position signals: 364 points
# Backtesting BCH-USD: 364 aligned price points with 364 position signals
# Trading activity: 180 entries, 184 exits
# Exposure for BCH-USD: Min=29.60%, Mean=40.58%, Max=100.00%
#
# Processing ADA-USD:
#   - Price series: 364 points from 2021-01-01 to 2021-12-30
#   - Position signals: 364 points
# Backtesting ADA-USD: 364 aligned price points with 364 position signals
# Trading activity: 159 entries, 205 exits
# Exposure for ADA-USD: Min=-3.13%, Mean=-0.27%, Max=2.94%
#
# Processing LINK-USD:
#   - Price series: 364 points from 2021-01-01 to 2021-12-30
#   - Position signals: 364 points
# Backtesting LINK-USD: 364 aligned price points with 364 position signals
# Trading activity: 185 entries, 179 exits
# Exposure for LINK-USD: Min=-67716.74%, Mean=-181.83%, Max=28227.77%
#
# Processing BNB-USD:
#   - Price series: 364 points from 2021-01-01 to 2021-12-30
#   - Position signals: 364 points
# Backtesting BNB-USD: 364 aligned price points with 364 position signals
# Trading activity: 162 entries, 202 exits
# Exposure for BNB-USD: Min=-398.89%, Mean=33.72%, Max=1096.08%
#
# Processing XLM-USD:
#   - Price series: 364 points from 2021-01-01 to 2021-12-30
#   - Position signals: 364 points
# Backtesting XLM-USD: 364 aligned price points with 364 position signals
# Trading activity: 172 entries, 192 exits
# Exposure for XLM-USD: Min=-0.65%, Mean=-0.01%, Max=0.73%
#
# Creating equal-weight portfolio with 9 assets, 11.11% weight each
#
# Portfolio Performance:
#   - Total Return: -340.78%
#   - Annualized Return: nan%
#   - Sharpe Ratio: -0.57
#   - Max Drawdown: -479.71%
#   - Win Rate: 45.33%
# /var/folders/b6/28cdp6ds16786vjhx3pz3jlr0000gn/T/ipykernel_84656/3910470318.py:341: RuntimeWarning: invalid value encountered in scalar power
#   annualized_return = (1 + total_return) ** (1 / years) - 1 if years > 0 else 0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ================================================================================
# Processing period 2022 (2022-01-01 to 2022-12-31)
# Cryptocurrencies: BTC-USD, ETH-USD, BNB-USD, SOL-USD, ADA-USD, XRP-USD, DOT1-USD, LUNA1-USD, AVAX-USD, DOGE-USD
# ================================================================================
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['DOT1-USD']: YFPricesMissingError('possibly delisted; no price data found  (1d 2021-12-02 -> 2022-12-31)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# No data found for DOT1-USD between 2021-12-02 and 2022-12-31
# [*********************100%***********************]  1 of 1 completed
# /opt/homebrew/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Data summary:
#   - Price data: 364 days from 2022-01-01 to 2022-12-30
#   - Returns data: 364 days
#   - Available tickers: BTC-USD, ETH-USD, BNB-USD, SOL-USD, ADA-USD, XRP-USD, LUNA1-USD, AVAX-USD, DOGE-USD
#
# ------------------------------------------------------------
# Processing BTC-USD for period 2022
# Detecting changepoints for BTC-USD...
# Detected 0 changepoints in series of length 364
# Generating trading signals for BTC-USD...
# Signal stats - Mean: 0.0207, StdDev: 0.6123, Min: -0.9983, Max: 0.9984
# Position distribution: 51.6% long, 48.4% short
# Generated 364 position signals for BTC-USD
#
# ------------------------------------------------------------
# Processing ETH-USD for period 2022
# Detecting changepoints for ETH-USD...
# Detected 0 changepoints in series of length 364
# Generating trading signals for ETH-USD...
# Signal stats - Mean: 0.0166, StdDev: 0.6450, Min: -0.9970, Max: 0.9959
# Position distribution: 52.7% long, 47.3% short
# Generated 364 position signals for ETH-USD
#
# ------------------------------------------------------------
# Processing BNB-USD for period 2022
# Detecting changepoints for BNB-USD...
# Detected 0 changepoints in series of length 364
# Generating trading signals for BNB-USD...
# Signal stats - Mean: 0.0171, StdDev: 0.6495, Min: -0.9978, Max: 0.9950
# Position distribution: 49.7% long, 50.3% short
# Generated 364 position signals for BNB-USD
#
# ------------------------------------------------------------
# Processing SOL-USD for period 2022
# Detecting changepoints for SOL-USD...
# Detected 0 changepoints in series of length 364
# Generating trading signals for SOL-USD...
# Signal stats - Mean: 0.0198, StdDev: 0.6625, Min: -0.9994, Max: 0.9985
# Position distribution: 50.3% long, 49.7% short
# Generated 364 position signals for SOL-USD
#
# ------------------------------------------------------------
# Processing ADA-USD for period 2022
# Detecting changepoints for ADA-USD...
# Detected 0 changepoints in series of length 364
# Generating trading signals for ADA-USD...
# Signal stats - Mean: 0.0042, StdDev: 0.6371, Min: -0.9958, Max: 0.9966
# Position distribution: 50.5% long, 49.5% short
# Generated 364 position signals for ADA-USD
#
# ------------------------------------------------------------
# Processing XRP-USD for period 2022
# Detecting changepoints for XRP-USD...
# Detected 0 changepoints in series of length 364
# Generating trading signals for XRP-USD...
# Signal stats - Mean: -0.0114, StdDev: 0.6366, Min: -0.9965, Max: 0.9979
# Position distribution: 50.8% long, 49.2% short
# Generated 364 position signals for XRP-USD
#
# ------------------------------------------------------------
# Processing LUNA1-USD for period 2022
# Detecting changepoints for LUNA1-USD...
# Error generating signals for LUNA1-USD: min() arg is an empty sequence
#
# ------------------------------------------------------------
# Processing AVAX-USD for period 2022
# Detecting changepoints for AVAX-USD...
# Detected 0 changepoints in series of length 364
# Generating trading signals for AVAX-USD...
# Traceback (most recent call last):
#   File "/var/folders/b6/28cdp6ds16786vjhx3pz3jlr0000gn/T/ipykernel_84656/3910470318.py", line 444, in main
#     changepoints = detect_changepoints(returns, lookback_window=params['lookback_window'])
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/b6/28cdp6ds16786vjhx3pz3jlr0000gn/T/ipykernel_84656/3910470318.py", line 125, in detect_changepoints
#     result = algo.predict(pen=lookback_window)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.11/site-packages/ruptures/detection/pelt.py", line 130, in predict
#     partition = self._seg(pen)
#                 ^^^^^^^^^^^^^^
#   File "/opt/homebrew/lib/python3.11/site-packages/ruptures/detection/pelt.py", line 75, in _seg
#     partitions[bkp] = min(subproblems, key=lambda d: sum(d.values()))
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ValueError: min() arg is an empty sequence
# Signal stats - Mean: 0.0041, StdDev: 0.6709, Min: -0.9995, Max: 0.9949
# Position distribution: 49.2% long, 50.8% short
# Generated 364 position signals for AVAX-USD
#
# ------------------------------------------------------------
# Processing DOGE-USD for period 2022
# Detecting changepoints for DOGE-USD...
# Detected 0 changepoints in series of length 364
# Generating trading signals for DOGE-USD...
# Signal stats - Mean: -0.0086, StdDev: 0.5894, Min: -0.9934, Max: 0.9984
# Position distribution: 50.3% long, 49.7% short
# Generated 364 position signals for DOGE-USD
#
# Processing BTC-USD:
#   - Price series: 364 points from 2022-01-01 to 2022-12-30
#   - Position signals: 364 points
# Backtesting BTC-USD: 364 aligned price points with 364 position signals
# Trading activity: 188 entries, 176 exits
# Exposure for BTC-USD: Min=46.77%, Mean=86.35%, Max=108.23%
#
# Processing ETH-USD:
#   - Price series: 364 points from 2022-01-01 to 2022-12-30
#   - Position signals: 364 points
# Backtesting ETH-USD: 364 aligned price points with 364 position signals
# Trading activity: 192 entries, 172 exits
# Exposure for ETH-USD: Min=-7024.05%, Mean=157.10%, Max=14257.44%
#
# Processing BNB-USD:
#   - Price series: 364 points from 2022-01-01 to 2022-12-30
#   - Position signals: 364 points
# Backtesting BNB-USD: 364 aligned price points with 364 position signals
# Trading activity: 181 entries, 183 exits
# Exposure for BNB-USD: Min=48.20%, Mean=79.19%, Max=100.00%
#
# Processing SOL-USD:
#   - Price series: 364 points from 2022-01-01 to 2022-12-30
#   - Position signals: 364 points
# Backtesting SOL-USD: 364 aligned price points with 364 position signals
# Trading activity: 183 entries, 181 exits
# Exposure for SOL-USD: Min=-57645.62%, Mean=-107.62%, Max=4801.93%
#
# Processing ADA-USD:
#   - Price series: 364 points from 2022-01-01 to 2022-12-30
#   - Position signals: 364 points
# Backtesting ADA-USD: 364 aligned price points with 364 position signals
# Trading activity: 184 entries, 180 exits
# Exposure for ADA-USD: Min=-1.51%, Mean=0.01%, Max=1.59%
#
# Processing XRP-USD:
#   - Price series: 364 points from 2022-01-01 to 2022-12-30
#   - Position signals: 364 points
# Backtesting XRP-USD: 364 aligned price points with 364 position signals
# Trading activity: 185 entries, 179 exits
# Exposure for XRP-USD: Min=-0.88%, Mean=0.01%, Max=0.88%
#
# Processing AVAX-USD:
#   - Price series: 364 points from 2022-01-01 to 2022-12-30
#   - Position signals: 364 points
# Backtesting AVAX-USD: 364 aligned price points with 364 position signals
# Trading activity: 179 entries, 185 exits
# Exposure for AVAX-USD: Min=-12948.09%, Mean=34.30%, Max=8256.52%
#
# Processing DOGE-USD:
#   - Price series: 364 points from 2022-01-01 to 2022-12-30
#   - Position signals: 364 points
# Backtesting DOGE-USD: 364 aligned price points with 364 position signals
# Trading activity: 183 entries, 181 exits
# Exposure for DOGE-USD: Min=-0.18%, Mean=0.00%, Max=0.19%
#
# Creating equal-weight portfolio with 8 assets, 12.50% weight each
#
# Portfolio Performance:
#   - Total Return: 1155.65%
#   - Annualized Return: 1173.28%
#   - Sharpe Ratio: 1.39
#   - Max Drawdown: -31.38%
#   - Win Rate: 50.55%
#
# ================================================================================
# Processing period 2023 (2023-01-01 to 2023-12-31)
# Cryptocurrencies: BTC-USD, ETH-USD, BNB-USD, XRP-USD, ADA-USD, DOGE-USD, MATIC-USD, DOT1-USD, LTC-USD, SHIB-USD
# ================================================================================
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['DOT1-USD']: YFPricesMissingError('possibly delisted; no price data found  (1d 2022-12-02 -> 2023-12-31)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# No data found for DOT1-USD between 2022-12-02 and 2023-12-31
# Warning: SHIB-USD has 316 zero or near-zero returns (possible stale data)
#
# Data summary:
#   - Price data: 364 days from 2023-01-01 to 2023-12-30
#   - Returns data: 364 days
#   - Available tickers: BTC-USD, ETH-USD, BNB-USD, XRP-USD, ADA-USD, DOGE-USD, MATIC-USD, LTC-USD, SHIB-USD
#
# ------------------------------------------------------------
# Processing BTC-USD for period 2023
# Detecting changepoints for BTC-USD...
# Detected 0 changepoints in series of length 364
# Generating trading signals for BTC-USD...
# /opt/homebrew/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Signal stats - Mean: -0.0262, StdDev: 0.6211, Min: -0.9916, Max: 0.9980
# Position distribution: 42.3% long, 57.7% short
# Generated 364 position signals for BTC-USD
#
# ------------------------------------------------------------
# Processing ETH-USD for period 2023
# Detecting changepoints for ETH-USD...
# Detected 0 changepoints in series of length 364
# Generating trading signals for ETH-USD...
# Signal stats - Mean: -0.0118, StdDev: 0.6365, Min: -0.9959, Max: 0.9989
# Position distribution: 47.8% long, 52.2% short
# Generated 364 position signals for ETH-USD
#
# ------------------------------------------------------------
# Processing BNB-USD for period 2023
# Detecting changepoints for BNB-USD...
# Detected 0 changepoints in series of length 364
# Generating trading signals for BNB-USD...
# Signal stats - Mean: 0.0144, StdDev: 0.6026, Min: -0.9980, Max: 0.9975
# Position distribution: 51.9% long, 48.1% short
# Generated 364 position signals for BNB-USD
#
# ------------------------------------------------------------
# Processing XRP-USD for period 2023
# Detecting changepoints for XRP-USD...
# Detected 0 changepoints in series of length 364
# Generating trading signals for XRP-USD...
# Signal stats - Mean: -0.0245, StdDev: 0.4764, Min: -0.9556, Max: 0.9930
# Position distribution: 44.8% long, 55.2% short
# Generated 364 position signals for XRP-USD
#
# ------------------------------------------------------------
# Processing ADA-USD for period 2023
# Detecting changepoints for ADA-USD...
# Detected 0 changepoints in series of length 364
# Generating trading signals for ADA-USD...
# Signal stats - Mean: -0.0164, StdDev: 0.6362, Min: -0.9868, Max: 0.9976
# Position distribution: 47.5% long, 52.5% short
# Generated 364 position signals for ADA-USD
#
# ------------------------------------------------------------
# Processing DOGE-USD for period 2023
# Detecting changepoints for DOGE-USD...
# Detected 0 changepoints in series of length 364
# Generating trading signals for DOGE-USD...
# Signal stats - Mean: 0.0203, StdDev: 0.6281, Min: -0.9911, Max: 0.9970
# Position distribution: 52.5% long, 47.5% short
# Generated 364 position signals for DOGE-USD
#
# ------------------------------------------------------------
# Processing MATIC-USD for period 2023
# Detecting changepoints for MATIC-USD...
# Detected 0 changepoints in series of length 364
# Generating trading signals for MATIC-USD...
# Signal stats - Mean: 0.0042, StdDev: 0.6602, Min: -0.9983, Max: 0.9967
# Position distribution: 51.4% long, 48.6% short
# Generated 364 position signals for MATIC-USD
#
# ------------------------------------------------------------
# Processing LTC-USD for period 2023
# Detecting changepoints for LTC-USD...
# Detected 0 changepoints in series of length 364
# Generating trading signals for LTC-USD...
# Signal stats - Mean: 0.0173, StdDev: 0.6308, Min: -0.9949, Max: 0.9969
# Position distribution: 51.4% long, 48.6% short
# Generated 364 position signals for LTC-USD
#
# ------------------------------------------------------------
# Processing SHIB-USD for period 2023
# Detecting changepoints for SHIB-USD...
# Detected 0 changepoints in series of length 364
# Generating trading signals for SHIB-USD...
# Signal stats - Mean: -0.0177, StdDev: 0.4493, Min: -0.9962, Max: 0.9980
# Position distribution: 21.7% long, 78.3% short
# Generated 364 position signals for SHIB-USD
#
# Processing BTC-USD:
#   - Price series: 364 points from 2023-01-01 to 2023-12-30
#   - Position signals: 364 points
# Backtesting BTC-USD: 364 aligned price points with 364 position signals
# Trading activity: 154 entries, 210 exits
# Exposure for BTC-USD: Min=33.54%, Mean=46.31%, Max=100.00%
#
# Processing ETH-USD:
#   - Price series: 364 points from 2023-01-01 to 2023-12-30
#   - Position signals: 364 points
# Backtesting ETH-USD: 364 aligned price points with 364 position signals
# Trading activity: 174 entries, 190 exits
# Exposure for ETH-USD: Min=30.76%, Mean=42.44%, Max=100.00%
#
# Processing BNB-USD:
#   - Price series: 364 points from 2023-01-01 to 2023-12-30
#   - Position signals: 364 points
# Backtesting BNB-USD: 364 aligned price points with 364 position signals
# Trading activity: 189 entries, 175 exits
# Exposure for BNB-USD: Min=48.12%, Mean=78.10%, Max=100.00%
#
# Processing XRP-USD:
#   - Price series: 364 points from 2023-01-01 to 2023-12-30
#   - Position signals: 364 points
# Backtesting XRP-USD: 364 aligned price points with 364 position signals
# Trading activity: 163 entries, 201 exits
# Exposure for XRP-USD: Min=-0.81%, Mean=-0.06%, Max=0.82%
#
# Processing ADA-USD:
#   - Price series: 364 points from 2023-01-01 to 2023-12-30
#   - Position signals: 364 points
# Backtesting ADA-USD: 364 aligned price points with 364 position signals
# Trading activity: 173 entries, 191 exits
# Exposure for ADA-USD: Min=-0.65%, Mean=-0.01%, Max=0.66%
#
# Processing DOGE-USD:
#   - Price series: 364 points from 2023-01-01 to 2023-12-30
#   - Position signals: 364 points
# Backtesting DOGE-USD: 364 aligned price points with 364 position signals
# Trading activity: 191 entries, 173 exits
# Exposure for DOGE-USD: Min=-0.10%, Mean=0.00%, Max=0.10%
#
# Processing MATIC-USD:
#   - Price series: 364 points from 2023-01-01 to 2023-12-30
#   - Position signals: 364 points
# Backtesting MATIC-USD: 364 aligned price points with 364 position signals
# Trading activity: 187 entries, 177 exits
# Exposure for MATIC-USD: Min=-1.53%, Mean=0.02%, Max=1.52%
#
# Processing LTC-USD:
#   - Price series: 364 points from 2023-01-01 to 2023-12-30
#   - Position signals: 364 points
# Backtesting LTC-USD: 364 aligned price points with 364 position signals
# Trading activity: 187 entries, 177 exits
# Exposure for LTC-USD: Min=58.05%, Mean=113.98%, Max=334.83%
#
# Processing SHIB-USD:
#   - Price series: 364 points from 2023-01-01 to 2023-12-30
#   - Position signals: 364 points
# Backtesting SHIB-USD: 364 aligned price points with 364 position signals
# Trading activity: 79 entries, 285 exits
# Exposure for SHIB-USD: Min=-0.00%, Mean=-0.00%, Max=0.00%
#
# Creating equal-weight portfolio with 9 assets, 11.11% weight each
#
# Portfolio Performance:
#   - Total Return: 0.86%
#   - Annualized Return: 0.86%
#   - Sharpe Ratio: 0.34
#   - Max Drawdown: -40.40%
#   - Win Rate: 39.84%
#
# ================================================================================
# Processing period 2024 (2024-01-01 to 2024-12-31)
# Cryptocurrencies: BTC-USD, ETH-USD, BNB-USD, XRP-USD, ADA-USD, DOGE-USD, SOL-USD, DOT1-USD, LTC-USD, AVAX-USD
# ================================================================================
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['DOT1-USD']: YFPricesMissingError('possibly delisted; no price data found  (1d 2023-12-02 -> 2024-12-31)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# No data found for DOT1-USD between 2023-12-02 and 2024-12-31
#
# Data summary:
#   - Price data: 365 days from 2024-01-01 to 2024-12-30
#   - Returns data: 365 days
#   - Available tickers: BTC-USD, ETH-USD, BNB-USD, XRP-USD, ADA-USD, DOGE-USD, SOL-USD, LTC-USD, AVAX-USD
#
# ------------------------------------------------------------
# Processing BTC-USD for period 2024
# Detecting changepoints for BTC-USD...
# /opt/homebrew/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Detected 0 changepoints in series of length 365
# Generating trading signals for BTC-USD...
# Signal stats - Mean: -0.0242, StdDev: 0.6409, Min: -0.9883, Max: 0.9964
# Position distribution: 46.8% long, 53.2% short
# Generated 365 position signals for BTC-USD
#
# ------------------------------------------------------------
# Processing ETH-USD for period 2024
# Detecting changepoints for ETH-USD...
# Detected 0 changepoints in series of length 365
# Generating trading signals for ETH-USD...
# Signal stats - Mean: -0.0145, StdDev: 0.6518, Min: -0.9937, Max: 0.9977
# Position distribution: 49.3% long, 50.7% short
# Generated 365 position signals for ETH-USD
#
# ------------------------------------------------------------
# Processing BNB-USD for period 2024
# Detecting changepoints for BNB-USD...
# Detected 0 changepoints in series of length 365
# Generating trading signals for BNB-USD...
# Signal stats - Mean: -0.0444, StdDev: 0.6439, Min: -0.9922, Max: 0.9990
# Position distribution: 46.3% long, 53.7% short
# Generated 365 position signals for BNB-USD
#
# ------------------------------------------------------------
# Processing XRP-USD for period 2024
# Detecting changepoints for XRP-USD...
# Detected 0 changepoints in series of length 365
# Generating trading signals for XRP-USD...
# Signal stats - Mean: -0.0518, StdDev: 0.5777, Min: -0.9925, Max: 0.9925
# Position distribution: 46.3% long, 53.7% short
# Generated 365 position signals for XRP-USD
#
# ------------------------------------------------------------
# Processing ADA-USD for period 2024
# Detecting changepoints for ADA-USD...
# Detected 0 changepoints in series of length 365
# Generating trading signals for ADA-USD...
# Signal stats - Mean: -0.0362, StdDev: 0.6433, Min: -0.9971, Max: 0.9969
# Position distribution: 48.2% long, 51.8% short
# Generated 365 position signals for ADA-USD
#
# ------------------------------------------------------------
# Processing DOGE-USD for period 2024
# Detecting changepoints for DOGE-USD...
# Detected 0 changepoints in series of length 365
# Generating trading signals for DOGE-USD...
# Signal stats - Mean: -0.0289, StdDev: 0.6537, Min: -0.9896, Max: 0.9994
# Position distribution: 45.5% long, 54.5% short
# Generated 365 position signals for DOGE-USD
#
# ------------------------------------------------------------
# Processing SOL-USD for period 2024
# Detecting changepoints for SOL-USD...
# Detected 0 changepoints in series of length 365
# Generating trading signals for SOL-USD...
# Signal stats - Mean: -0.0414, StdDev: 0.6911, Min: -0.9961, Max: 0.9952
# Position distribution: 46.6% long, 53.4% short
# Generated 365 position signals for SOL-USD
#
# ------------------------------------------------------------
# Processing LTC-USD for period 2024
# Detecting changepoints for LTC-USD...
# Detected 0 changepoints in series of length 365
# Generating trading signals for LTC-USD...
# Signal stats - Mean: -0.0054, StdDev: 0.6232, Min: -0.9965, Max: 0.9933
# Position distribution: 51.8% long, 48.2% short
# Generated 365 position signals for LTC-USD
#
# ------------------------------------------------------------
# Processing AVAX-USD for period 2024
# Detecting changepoints for AVAX-USD...
# Detected 0 changepoints in series of length 365
# Generating trading signals for AVAX-USD...
# Signal stats - Mean: -0.0508, StdDev: 0.6848, Min: -0.9940, Max: 0.9960
# Position distribution: 46.3% long, 53.7% short
# Generated 365 position signals for AVAX-USD
#
# Processing BTC-USD:
#   - Price series: 365 points from 2024-01-01 to 2024-12-30
#   - Position signals: 365 points
# Backtesting BTC-USD: 365 aligned price points with 365 position signals
# Trading activity: 171 entries, 194 exits
# Exposure for BTC-USD: Min=31.55%, Mean=43.37%, Max=100.00%
#
# Processing ETH-USD:
#   - Price series: 365 points from 2024-01-01 to 2024-12-30
#   - Position signals: 365 points
# Backtesting ETH-USD: 365 aligned price points with 365 position signals
# Trading activity: 180 entries, 185 exits
# Exposure for ETH-USD: Min=29.62%, Mean=41.64%, Max=100.00%
#
# Processing BNB-USD:
#   - Price series: 365 points from 2024-01-01 to 2024-12-30
#   - Position signals: 365 points
# Backtesting BNB-USD: 365 aligned price points with 365 position signals
# Trading activity: 169 entries, 196 exits
# Exposure for BNB-USD: Min=30.77%, Mean=44.69%, Max=100.00%
#
# Processing XRP-USD:
#   - Price series: 365 points from 2024-01-01 to 2024-12-30
#   - Position signals: 365 points
# Backtesting XRP-USD: 365 aligned price points with 365 position signals
# Trading activity: 169 entries, 196 exits
# Exposure for XRP-USD: Min=-2.70%, Mean=-0.03%, Max=2.67%
#
# Processing ADA-USD:
#   - Price series: 365 points from 2024-01-01 to 2024-12-30
#   - Position signals: 365 points
# Backtesting ADA-USD: 365 aligned price points with 365 position signals
# Trading activity: 176 entries, 189 exits
# Exposure for ADA-USD: Min=-1.23%, Mean=-0.01%, Max=1.22%
#
# Processing DOGE-USD:
#   - Price series: 365 points from 2024-01-01 to 2024-12-30
#   - Position signals: 365 points
# Backtesting DOGE-USD: 365 aligned price points with 365 position signals
# Trading activity: 166 entries, 199 exits
# Exposure for DOGE-USD: Min=-0.43%, Mean=-0.01%, Max=0.47%
#
# Processing SOL-USD:
#   - Price series: 365 points from 2024-01-01 to 2024-12-30
#   - Position signals: 365 points
# Backtesting SOL-USD: 365 aligned price points with 365 position signals
# Trading activity: 170 entries, 195 exits
# Exposure for SOL-USD: Min=59.04%, Mean=100.20%, Max=373.43%
#
# Processing LTC-USD:
#   - Price series: 365 points from 2024-01-01 to 2024-12-30
#   - Position signals: 365 points
# Backtesting LTC-USD: 365 aligned price points with 365 position signals
# Trading activity: 189 entries, 176 exits
# Exposure for LTC-USD: Min=62.66%, Mean=98.68%, Max=249.86%
#
# Processing AVAX-USD:
#   - Price series: 365 points from 2024-01-01 to 2024-12-30
#   - Position signals: 365 points
# Backtesting AVAX-USD: 365 aligned price points with 365 position signals
# Trading activity: 169 entries, 196 exits
# Exposure for AVAX-USD: Min=-6468.51%, Mean=-8.10%, Max=5521.60%
#
# Creating equal-weight portfolio with 9 assets, 11.11% weight each
#
# Portfolio Performance:
#   - Total Return: -258.11%
#   - Annualized Return: nan%
#   - Sharpe Ratio: -0.80
#   - Max Drawdown: -395.91%
#   - Win Rate: 48.77%
#
# ================================================================================
# Processing period 2025_YTD (2025-01-01 to 2025-03-07)
# Cryptocurrencies: BTC-USD, ETH-USD, BNB-USD, XRP-USD, ADA-USD, DOGE-USD, SOL-USD, DOT1-USD, LTC-USD, AVAX-USD
# ================================================================================
# /var/folders/b6/28cdp6ds16786vjhx3pz3jlr0000gn/T/ipykernel_84656/3910470318.py:341: RuntimeWarning: invalid value encountered in scalar power
#   annualized_return = (1 + total_return) ** (1 / years) - 1 if years > 0 else 0
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['DOT1-USD']: YFPricesMissingError('possibly delisted; no price data found  (1d 2024-12-02 -> 2025-03-07)')
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# /opt/homebrew/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# No data found for DOT1-USD between 2024-12-02 and 2025-03-07
#
# Data summary:
#   - Price data: 65 days from 2025-01-01 to 2025-03-06
#   - Returns data: 65 days
#   - Available tickers: BTC-USD, ETH-USD, BNB-USD, XRP-USD, ADA-USD, DOGE-USD, SOL-USD, LTC-USD, AVAX-USD
#
# ------------------------------------------------------------
# Processing BTC-USD for period 2025_YTD
# Detecting changepoints for BTC-USD...
# Detected 0 changepoints in series of length 65
# Generating trading signals for BTC-USD...
# Signal stats - Mean: 0.0470, StdDev: 0.1566, Min: -0.3224, Max: 0.5602
# Position distribution: 66.2% long, 33.8% short
# Generated 65 position signals for BTC-USD
#
# ------------------------------------------------------------
# Processing ETH-USD for period 2025_YTD
# Detecting changepoints for ETH-USD...
# Detected 0 changepoints in series of length 65
# Generating trading signals for ETH-USD...
# WARNING:tensorflow:5 out of the last 16 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x3c05a5620> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 18 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x3c05a5620> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Signal stats - Mean: 0.0219, StdDev: 0.1433, Min: -0.3866, Max: 0.4448
# Position distribution: 56.9% long, 43.1% short
# Generated 65 position signals for ETH-USD
#
# ------------------------------------------------------------
# Processing BNB-USD for period 2025_YTD
# Detecting changepoints for BNB-USD...
# Detected 0 changepoints in series of length 65
# Generating trading signals for BNB-USD...
# Signal stats - Mean: -0.0304, StdDev: 0.1059, Min: -0.3014, Max: 0.2813
# Position distribution: 41.5% long, 58.5% short
# Generated 65 position signals for BNB-USD
#
# ------------------------------------------------------------
# Processing XRP-USD for period 2025_YTD
# Detecting changepoints for XRP-USD...
# Detected 0 changepoints in series of length 65
# Generating trading signals for XRP-USD...
# Signal stats - Mean: 0.0742, StdDev: 0.1631, Min: -0.2582, Max: 0.7847
# Position distribution: 72.3% long, 27.7% short
# Generated 65 position signals for XRP-USD
#
# ------------------------------------------------------------
# Processing ADA-USD for period 2025_YTD
# Detecting changepoints for ADA-USD...
# Detected 0 changepoints in series of length 65
# Generating trading signals for ADA-USD...
# Signal stats - Mean: -0.0143, StdDev: 0.1134, Min: -0.2887, Max: 0.5488
# Position distribution: 38.5% long, 61.5% short
# Generated 65 position signals for ADA-USD
#
# ------------------------------------------------------------
# Processing DOGE-USD for period 2025_YTD
# Detecting changepoints for DOGE-USD...
# Detected 0 changepoints in series of length 65
# Generating trading signals for DOGE-USD...
# Signal stats - Mean: 0.0550, StdDev: 0.1709, Min: -0.3390, Max: 0.5343
# Position distribution: 63.1% long, 36.9% short
# Generated 65 position signals for DOGE-USD
#
# ------------------------------------------------------------
# Processing SOL-USD for period 2025_YTD
# Detecting changepoints for SOL-USD...
# Detected 0 changepoints in series of length 65
# Generating trading signals for SOL-USD...
# Signal stats - Mean: 0.0317, StdDev: 0.1637, Min: -0.3141, Max: 0.6464
# Position distribution: 55.4% long, 44.6% short
# Generated 65 position signals for SOL-USD
#
# ------------------------------------------------------------
# Processing LTC-USD for period 2025_YTD
# Detecting changepoints for LTC-USD...
# Detected 0 changepoints in series of length 65
# Generating trading signals for LTC-USD...
# Signal stats - Mean: 0.1298, StdDev: 0.1492, Min: -0.1522, Max: 0.5538
# Position distribution: 83.1% long, 16.9% short
# Generated 65 position signals for LTC-USD
#
# ------------------------------------------------------------
# Processing AVAX-USD for period 2025_YTD
# Detecting changepoints for AVAX-USD...
# Detected 0 changepoints in series of length 65
# Generating trading signals for AVAX-USD...
# Signal stats - Mean: 0.0382, StdDev: 0.1053, Min: -0.2408, Max: 0.2857
# Position distribution: 64.6% long, 35.4% short
# Generated 65 position signals for AVAX-USD
#
# Processing BTC-USD:
#   - Price series: 65 points from 2025-01-01 to 2025-03-06
#   - Position signals: 65 points
# Backtesting BTC-USD: 65 aligned price points with 65 position signals
# Trading activity: 43 entries, 22 exits
# Exposure for BTC-USD: Min=29.11%, Mean=54.89%, Max=100.00%
#
# Processing ETH-USD:
#   - Price series: 65 points from 2025-01-01 to 2025-03-06
#   - Position signals: 65 points
# Backtesting ETH-USD: 65 aligned price points with 65 position signals
# Trading activity: 37 entries, 28 exits
# Exposure for ETH-USD: Min=24.49%, Mean=43.15%, Max=100.00%
#
# Processing BNB-USD:
#   - Price series: 65 points from 2025-01-01 to 2025-03-06
#   - Position signals: 65 points
# Backtesting BNB-USD: 65 aligned price points with 65 position signals
# Trading activity: 27 entries, 38 exits
# Exposure for BNB-USD: Min=47.65%, Mean=72.65%, Max=100.00%
#
# Processing XRP-USD:
#   - Price series: 65 points from 2025-01-01 to 2025-03-06
#   - Position signals: 65 points
# Backtesting XRP-USD: 65 aligned price points with 65 position signals
# Trading activity: 47 entries, 18 exits
# Exposure for XRP-USD: Min=-3.23%, Mean=1.21%, Max=3.28%
#
# Processing ADA-USD:
#   - Price series: 65 points from 2025-01-01 to 2025-03-06
#   - Position signals: 65 points
# Backtesting ADA-USD: 65 aligned price points with 65 position signals
# Trading activity: 25 entries, 40 exits
# Exposure for ADA-USD: Min=-1.12%, Mean=-0.18%, Max=1.13%
#
# Processing DOGE-USD:
#   - Price series: 65 points from 2025-01-01 to 2025-03-06
#   - Position signals: 65 points
# Backtesting DOGE-USD: 65 aligned price points with 65 position signals
# Trading activity: 41 entries, 24 exits
# Exposure for DOGE-USD: Min=-0.40%, Mean=0.08%, Max=0.42%
#
# Processing SOL-USD:
#   - Price series: 65 points from 2025-01-01 to 2025-03-06
#   - Position signals: 65 points
# Backtesting SOL-USD: 65 aligned price points with 65 position signals
# Trading activity: 36 entries, 29 exits
# Exposure for SOL-USD: Min=63.49%, Mean=90.67%, Max=169.28%
#
# Processing LTC-USD:
#   - Price series: 65 points from 2025-01-01 to 2025-03-06
#   - Position signals: 65 points
# Backtesting LTC-USD: 65 aligned price points with 65 position signals
# Trading activity: 54 entries, 11 exits
# Exposure for LTC-USD: Min=67.88%, Mean=92.91%, Max=159.51%
#
# Processing AVAX-USD:
#   - Price series: 65 points from 2025-01-01 to 2025-03-06
#   - Position signals: 65 points
# Backtesting AVAX-USD: 65 aligned price points with 65 position signals
# Trading activity: 42 entries, 23 exits
# Exposure for AVAX-USD: Min=-171.29%, Mean=-7.66%, Max=41.46%
#
# Creating equal-weight portfolio with 9 assets, 11.11% weight each
#
# Portfolio Performance:
#   - Total Return: 3566.75%
#   - Annualized Return: 83424531619.12%
#   - Sharpe Ratio: 1.97
#   - Max Drawdown: -33.09%
#   - Win Rate: 49.23%
#
# Backtest Results:
#       period                strategy  num_assets  total_return  \
# 0       2019  Equal Weight Portfolio        10.0     -0.403937
# 1       2019        Individual Asset         NaN           NaN
# 2       2019        Individual Asset         NaN           NaN
# 3       2019        Individual Asset         NaN           NaN
# 4       2019        Individual Asset         NaN           NaN
# ..       ...                     ...         ...           ...
# 66  2025_YTD        Individual Asset         NaN           NaN
# 67  2025_YTD        Individual Asset         NaN           NaN
# 68  2025_YTD        Individual Asset         NaN           NaN
# 69  2025_YTD        Individual Asset         NaN           NaN
# 70  2025_YTD        Individual Asset         NaN           NaN
#
#    annualized_return  sharpe_ratio  max_drawdown  win_rate  num_days  \
# 0          -0.405634     -0.528959     -0.617004   0.46978     363.0
# 1                NaN           NaN           NaN       NaN       NaN
# 2                NaN           NaN           NaN       NaN       NaN
# 3                NaN           NaN           NaN       NaN       NaN
# 4                NaN           NaN           NaN       NaN       NaN
# ..               ...           ...           ...       ...       ...
# 66               NaN           NaN           NaN       NaN       NaN
# 67               NaN           NaN           NaN       NaN       NaN
# 68               NaN           NaN           NaN       NaN       NaN
# 69               NaN           NaN           NaN       NaN       NaN
# 70               NaN           NaN           NaN       NaN       NaN
#
#       crypto  ... Avg Winning Trade [%] Avg Losing Trade [%]  \
# 0        NaN  ...                   NaN                  NaN
# 1    BTC-USD  ...                   nan            -1.968167
# 2    ETH-USD  ...              6.103094            -2.171967
# 3    XRP-USD  ...              4.213775            -2.103177
# 4    BCH-USD  ...               8.86375            -3.278497
# ..       ...  ...                   ...                  ...
# 66   ADA-USD  ...             14.050612            -2.738018
# 67  DOGE-USD  ...              7.833307            -3.729479
# 68   SOL-USD  ...              8.045759            -2.802857
# 69   LTC-USD  ...              8.099744            -3.138398
# 70  AVAX-USD  ...              5.930406            -3.733296
#
#    Avg Winning Trade Duration  Avg Losing Trade Duration  Profit Factor  \
# 0                         NaN                        NaT            NaN
# 1                         NaT            1 days 06:00:00       0.000000
# 2             3 days 04:48:00     1 days 08:49:55.200000       1.345704
# 3   3 days 01:08:34.285714285  1 days 09:05:48.387096774       1.023580
# 4             3 days 08:00:00  1 days 08:35:49.253731343       0.750449
# ..                        ...                        ...            ...
# 66            4 days 12:00:00  1 days 11:04:36.923076923       4.006937
# 67            3 days 10:00:00            1 days 07:30:00       1.672998
# 68  3 days 01:50:46.153846153            1 days 08:00:00       2.136778
# 69            3 days 21:20:00            4 days 00:00:00       3.172693
# 70            3 days 02:00:00  2 days 01:50:46.153846153       1.667632
#
#     Expectancy  Sharpe Ratio  Calmar Ratio  Omega Ratio  Sortino Ratio
# 0          NaN           NaN           NaN          NaN            NaN
# 1   -64.719532     -1.306177           nan     0.444649      -1.314306
# 2     0.815448      1.281170      1.935589     1.294362       2.604012
# 3     0.000105      0.082105      0.095523     1.013389       0.131776
# 4    -1.161596     -1.134171           nan     0.708592      -1.215930
# ..         ...           ...           ...          ...            ...
# 66    0.040055      3.402700     13.392678     1.952627       6.756261
# 67    0.004218      2.107154     11.442924     1.363286       3.506199
# 68    2.779830      3.551983    172.514421     1.676433       6.782133
# 69    3.359620      3.033355     64.103248     1.542401       4.968723
# 70    0.360121      1.775542     12.654066     1.286572       2.768423
#
# [71 rows x 38 columns]
#
# Equal Weight Portfolio Performance by Year:
#       period  total_return  sharpe_ratio  max_drawdown
# 0       2019     -0.403937     -0.528959     -0.617004
# 11      2020     -0.618529     -0.986161     -0.689924
# 22      2021     -3.407792     -0.571502     -4.797105
# 32      2022     11.556550      1.391007     -0.313760
# 41      2023      0.008552      0.339947     -0.404038
# 51      2024     -2.581120     -0.795755     -3.959123
# 61  2025_YTD     35.667529      1.971384     -0.330865

# %%
df_backtest = pd.read_csv("Backtested/equal_weight_8.csv")

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
df_backtest
# Out:
#       period                strategy  num_assets  total_return  \
# 0       2019  Equal Weight Portfolio        10.0     -0.403937
# 1       2019        Individual Asset         NaN           NaN
# 2       2019        Individual Asset         NaN           NaN
# 3       2019        Individual Asset         NaN           NaN
# 4       2019        Individual Asset         NaN           NaN
# 5       2019        Individual Asset         NaN           NaN
# 6       2019        Individual Asset         NaN           NaN
# 7       2019        Individual Asset         NaN           NaN
# 8       2019        Individual Asset         NaN           NaN
# 9       2019        Individual Asset         NaN           NaN
# 10      2019        Individual Asset         NaN           NaN
# 11      2020  Equal Weight Portfolio        10.0     -0.618529
# 12      2020        Individual Asset         NaN           NaN
# 13      2020        Individual Asset         NaN           NaN
# 14      2020        Individual Asset         NaN           NaN
# 15      2020        Individual Asset         NaN           NaN
# 16      2020        Individual Asset         NaN           NaN
# 17      2020        Individual Asset         NaN           NaN
# 18      2020        Individual Asset         NaN           NaN
# 19      2020        Individual Asset         NaN           NaN
# 20      2020        Individual Asset         NaN           NaN
# 21      2020        Individual Asset         NaN           NaN
# 22      2021  Equal Weight Portfolio         9.0     -3.407792
# 23      2021        Individual Asset         NaN           NaN
# 24      2021        Individual Asset         NaN           NaN
# 25      2021        Individual Asset         NaN           NaN
# 26      2021        Individual Asset         NaN           NaN
# 27      2021        Individual Asset         NaN           NaN
# 28      2021        Individual Asset         NaN           NaN
# 29      2021        Individual Asset         NaN           NaN
# 30      2021        Individual Asset         NaN           NaN
# 31      2021        Individual Asset         NaN           NaN
# 32      2022  Equal Weight Portfolio         8.0     11.556550
# 33      2022        Individual Asset         NaN           NaN
# 34      2022        Individual Asset         NaN           NaN
# 35      2022        Individual Asset         NaN           NaN
# 36      2022        Individual Asset         NaN           NaN
# 37      2022        Individual Asset         NaN           NaN
# 38      2022        Individual Asset         NaN           NaN
# 39      2022        Individual Asset         NaN           NaN
# 40      2022        Individual Asset         NaN           NaN
# 41      2023  Equal Weight Portfolio         9.0      0.008552
# 42      2023        Individual Asset         NaN           NaN
# 43      2023        Individual Asset         NaN           NaN
# 44      2023        Individual Asset         NaN           NaN
# 45      2023        Individual Asset         NaN           NaN
# 46      2023        Individual Asset         NaN           NaN
# 47      2023        Individual Asset         NaN           NaN
# 48      2023        Individual Asset         NaN           NaN
# 49      2023        Individual Asset         NaN           NaN
# 50      2023        Individual Asset         NaN           NaN
# 51      2024  Equal Weight Portfolio         9.0     -2.581120
# 52      2024        Individual Asset         NaN           NaN
# 53      2024        Individual Asset         NaN           NaN
# 54      2024        Individual Asset         NaN           NaN
# 55      2024        Individual Asset         NaN           NaN
# 56      2024        Individual Asset         NaN           NaN
# 57      2024        Individual Asset         NaN           NaN
# 58      2024        Individual Asset         NaN           NaN
# 59      2024        Individual Asset         NaN           NaN
# 60      2024        Individual Asset         NaN           NaN
# 61  2025_YTD  Equal Weight Portfolio         9.0     35.667529
# 62  2025_YTD        Individual Asset         NaN           NaN
# 63  2025_YTD        Individual Asset         NaN           NaN
# 64  2025_YTD        Individual Asset         NaN           NaN
# 65  2025_YTD        Individual Asset         NaN           NaN
# 66  2025_YTD        Individual Asset         NaN           NaN
# 67  2025_YTD        Individual Asset         NaN           NaN
# 68  2025_YTD        Individual Asset         NaN           NaN
# 69  2025_YTD        Individual Asset         NaN           NaN
# 70  2025_YTD        Individual Asset         NaN           NaN
#
#     annualized_return  sharpe_ratio  max_drawdown  win_rate  num_days  \
# 0       -4.056338e-01     -0.528959     -0.617004  0.469780     363.0
# 1                 NaN           NaN           NaN       NaN       NaN
# 2                 NaN           NaN           NaN       NaN       NaN
# 3                 NaN           NaN           NaN       NaN       NaN
# 4                 NaN           NaN           NaN       NaN       NaN
# 5                 NaN           NaN           NaN       NaN       NaN
# 6                 NaN           NaN           NaN       NaN       NaN
# 7                 NaN           NaN           NaN       NaN       NaN
# 8                 NaN           NaN           NaN       NaN       NaN
# 9                 NaN           NaN           NaN       NaN       NaN
# 10                NaN           NaN           NaN       NaN       NaN
# 11      -6.195379e-01     -0.986161     -0.689924  0.465753     364.0
# 12                NaN           NaN           NaN       NaN       NaN
# 13                NaN           NaN           NaN       NaN       NaN
# 14                NaN           NaN           NaN       NaN       NaN
# 15                NaN           NaN           NaN       NaN       NaN
# 16                NaN           NaN           NaN       NaN       NaN
# 17                NaN           NaN           NaN       NaN       NaN
# 18                NaN           NaN           NaN       NaN       NaN
# 19                NaN           NaN           NaN       NaN       NaN
# 20                NaN           NaN           NaN       NaN       NaN
# 21                NaN           NaN           NaN       NaN       NaN
# 22                NaN     -0.571502     -4.797105  0.453297     363.0
# 23                NaN           NaN           NaN       NaN       NaN
# 41              NaN               NaN                   NaN           NaN
# 42        33.626547        404.736302              362 days           3.0
# 43        42.229746        122.046080              340 days          27.0
# 44        60.460561         96.803594              346 days         192.0
# 45         0.195023          0.510984              350 days         193.0
# 46         0.115753          0.255361              315 days         164.0
# 47         0.027237          0.067648              344 days         182.0
# 48         0.307968          0.813424              337 days         180.0
# 49        28.668121         41.907860              291 days         178.0
# 50         0.000001          0.000003               96 days          69.0
# 51              NaN               NaN                   NaN           NaN
# 52        85.904280       3220.093977              363 days           3.0
# 53        55.904718        120.968740              340 days          23.0
# 54        14.474660        106.810365              356 days          35.0
# 55         0.267787          0.532223              313 days         186.0
# 56         0.172983          0.357994              250 days         164.0
# 57         0.058444          0.092745              163 days         182.0
# 58        47.021274         42.617509              112 days         159.0
# 59        26.007796         56.815688              296 days         175.0
# 60        11.960111         40.205704              307 days         166.0
# 61              NaN               NaN                   NaN           NaN
# 62       816.316300        113.480830               56 days           9.0
# 63        20.545449        125.141674               56 days           7.0
# 64        27.089365         48.519004               31 days          36.0
# 65         0.133936          0.977102               27 days          27.0
# 66         0.042250          0.394183               13 days          24.0
# 67         0.016356          0.059293               35 days          29.0
# 68        10.560949         18.343980                9 days          32.0
# 69         3.694593         15.008916               15 days          17.0
# 70         1.502662          4.906875               14 days          26.0
#
#     Total Closed Trades  Total Open Trades  Open Trade PnL  Win Rate [%]  \
# 0                   NaN                NaN             NaN           NaN
# 1                   4.0                1.0   -1.427600e+02      0.000000
# 2                 185.0                1.0   -1.326335e-01     32.432432
# 3                 187.0                1.0   -1.944740e-04     33.689840
# 4                  94.0                1.0    4.367746e+00     28.723404
# 5                 193.0                1.0   -2.645544e-03     30.569948
# 6                 173.0                1.0   -4.274734e-02     36.994220
# 7                 175.0                1.0   -4.595400e-05     37.142857
# 8                 183.0                1.0   -3.359400e-05     31.693989
# 9                 185.0                1.0   -1.340000e-05     36.756757
# 10                185.0                1.0   -9.697651e-02     34.594595
# 11                  NaN                NaN             NaN           NaN
# 12                  1.0                1.0   -1.744711e+02      0.000000
# 13                 28.0                1.0   -1.345602e+00     17.857143
# 14                180.0                1.0    1.059449e-01     34.444444
# 15                 11.0                1.0   -2.522673e-01     18.181818
# 16                177.0                1.0   -5.543185e-01     37.853107
# 17                195.0                1.0    2.936410e-02     30.769231
# 18                188.0                1.0   -3.813630e-02     33.510638
# 19                169.0                1.0   -1.669031e-01     37.278107
# 20                185.0                1.0   -1.840400e-04     32.972973
# 21                185.0                1.0    5.220516e-02     35.135135
# 22                  NaN                NaN             NaN           NaN
# 23                  2.0                1.0   -8.857498e+02     50.000000
# 24                 19.0                1.0   -5.748731e+00     47.368421
# 25                170.0                1.0   -8.396490e-04     37.058824
# 26                154.0                1.0   -1.482860e-01     45.454545
# 27                  5.0                1.0    9.951253e-01     40.000000
# 28                151.0                1.0   -1.360415e-03     41.721854
# 29                178.0                1.0   -1.997034e-02     38.202247
# 30                 62.0                1.0    1.198761e+00     38.709677
# 31                170.0                1.0   -2.683250e-04     40.000000
# 32                  NaN                NaN             NaN           NaN
# 28      129.896396       -24.754355               9.724059
# 29       34.798811       -37.401539               8.557068
# 30       96.504918       -21.720082              13.662870
# 31      131.152200       -20.662332               7.500402
# 32             NaN              NaN                    NaN
# 33       27.375315       -10.664540               4.354087
# 34       38.320440       -13.701285               6.566222
# 35       19.111705       -15.643366               5.381133
# 36       45.747156       -24.971154               7.048717
# 37       23.291525       -18.650506               5.587648
# 38       43.026417       -22.466900               5.129028
# 39       32.692354       -30.684143               7.553955
# 40      102.982236       -22.206599               7.501728
# 41             NaN              NaN                    NaN
# 42        0.129157        -1.300514               0.129157
# 43       21.565955        -4.983890               5.372259
# 44       17.307768        -8.044536               2.850307
# 45       52.400570       -25.605753               4.537609
# 46       35.213440       -24.084667               5.093193
# 47       16.807200       -21.703608               3.568399
# 48       25.432468       -17.543357               5.682340
# 49       25.925039       -13.500655               3.796982
# 50       22.900001       -12.712504              13.332254
# 51             NaN              NaN                    NaN
# 52       -3.183737        -3.311166                    NaN
# 53        8.003462        -5.341682               4.624908
# 54       21.620452        -8.912415               4.242650
# 55       71.205053       -15.663675               7.078452
# 56       71.598972       -10.986354               7.212192
# 57       78.636839       -12.659711               8.228943
# 58       27.069225       -11.586710               5.246418
# 59       26.452827       -18.827930               5.379405
# 60       41.646250       -16.754166               7.834199
# 61             NaN              NaN                    NaN
# 62        6.538828        -1.427772               3.120892
# 63        3.177166        -5.215430               2.079014
# 64       14.475444        -5.518288               2.637992
# 65       16.897160       -11.749422               9.903085
# 66       29.500201       -10.266954              14.050612
# 67       18.375276       -10.376508               7.833307
# 68       33.413415        -7.732985               8.045759
# 69       23.330724        -6.608889               8.099744
# 70       11.682957        -6.857261               5.930406
#
#     Avg Losing Trade [%] Avg Winning Trade Duration  \
# 0                    NaN                        NaN
# 1              -1.968167                        NaT
# 2              -2.171967            3 days 04:48:00
# 3              -2.103177  3 days 01:08:34.285714285
# 4              -3.278497            3 days 08:00:00
# 5              -2.962485  3 days 02:26:26.440677966
# 6              -2.536105            3 days 07:30:00
# 7              -2.371343  3 days 08:29:32.307692307
# 8              -2.675642  3 days 05:47:35.172413793
# 9              -2.764090  3 days 00:21:10.588235294
# 10             -2.734593            3 days 06:00:00
# 11                   NaN                        NaN
# 12             -2.211822                        NaT
# 13             -3.281319            3 days 19:12:00
# 14             -2.747030  3 days 10:50:19.354838709
# 15             -6.145298            2 days 12:00:00
# 16             -3.832124  3 days 04:39:24.179104477
# 17             -3.114503            3 days 06:24:00
# 18             -3.197609  3 days 08:22:51.428571428
# 19             -3.328384  3 days 13:42:51.428571428
# 20             -4.130974  3 days 08:15:44.262295082
# 21             -3.891529  3 days 01:50:46.153846153
# 22                   NaN                        NaN
# 23             -6.525978            3 days 00:00:00
# 24             -4.614627            2 days 18:40:00
# 25             -4.994763            3 days 08:00:00
# 26             -4.664636  3 days 12:41:08.571428571
# 27            -11.627084            2 days 00:00:00
# 28             -4.479650            3 days 16:00:00
# 29             -5.957337  3 days 03:31:45.882352941
# 30             -6.216780            3 days 01:00:00
# 31             -4.527620  3 days 05:17:38.823529411
# 32                   NaN                        NaN
